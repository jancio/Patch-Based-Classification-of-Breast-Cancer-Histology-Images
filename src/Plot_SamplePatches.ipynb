# %%
##################################################################################################
# Patch-based Classification of Breast Cancer Histology Images using CNNs
# LE48: MiniProject
# Jan Ondras (jo356), Trinity College
# 2017/2018
##################################################################################################

######################################################################################
# Plot sample images from all 4 classes, before and after stain normalisation
# Sample patches are saved in Dataset folder
######################################################################################
import matplotlib.pyplot as plt
import cv2
import glob


path_prefix = './../Dataset/SamplePatches/'
classes = ['Normal', 'Benign', 'InSitu', 'Invasive']

ID = 11 # 47
IMG_IDS = ['n047_0020', 
           'b047_0006', 
           'is004_0001', 
           'iv052_0022']

'''
n013_0017.tif
n016_0013.tif
n033_0001.tif
n047_0020.tif

b047_0006.tif

is004_0001.tif
is004_0031.tif

iv017_0009.tif
iv025_0027.tif
iv027_0011.tif
iv044_0026.tif
iv052_0022.tif
iv070_0015.tif
'''


print 'TARGETS = ['
# Plot 4 images before stain normalisation
plt.figure(figsize=(14,6.8))
for i, c in enumerate(classes):
    img = cv2.imread(path_prefix + 'notSN/patches_512_256/validation/' + c + '/' + IMG_IDS[i] + '.tif')
    print "'"+path_prefix + "notSN/patches_512_256/validation/" + c + "/"+ IMG_IDS[i] + '.tif'+"', "
    #     img = cv2.imread(glob.glob(path_prefix + 'notSN/patches_512_256/validation/' + c + '/*.tif')[ID])
#     print "'"+glob.glob(path_prefix + 'notSN/patches_512_256/validation/' + c + '/*.tif')[ID]+"', "
    plt.subplot(2,4,1+i)
    plt.axis('off')
    plt.imshow(img)
# plt.tight_layout(pad=-3.)
# plt.show()
print ']'

# Plot 4 images after stain normalisation
# plt.figure(figsize=(15,5))
for i, c in enumerate(classes):
    img = cv2.imread(path_prefix + 'SN/patches_512_256/validation/' + c + '/' + IMG_IDS[i] + '.tif')
#     img = cv2.imread(glob.glob(path_prefix + 'SN/patches_512_256/validation/' + c + '/*.tif')[ID])
    plt.subplot(2,4,5+i)
    plt.axis('off')
    plt.imshow(img)
plt.tight_layout(pad=-2.5)

# plt.savefig('./SN_patches.eps', format='eps', dpi=100)

plt.show()
# Out:
# TARGETS = [
# '/home/janciovec/Desktop/Patches/notSN/patches_512_256/validation/Normal/n047_0020.tif',
# '/home/janciovec/Desktop/Patches/notSN/patches_512_256/validation/Benign/b047_0006.tif',
# '/home/janciovec/Desktop/Patches/notSN/patches_512_256/validation/InSitu/is004_0001.tif',
# '/home/janciovec/Desktop/Patches/notSN/patches_512_256/validation/Invasive/iv052_0022.tif',
# ]

# %%
######################################################################################
# Plot sample images from all 4 classes, before and after stain normalisation
######################################################################################
import matplotlib.pyplot as plt
import cv2
import glob


path_prefix = './../Dataset/SamplePatches/'
classes = ['Normal', 'Benign', 'InSitu', 'Invasive']

ID = 11 # 47
IMG_IDS = ['n047_0020', 
           'b047_0006', 
           'is004_0001', 
           'iv052_0022']

'''
n013_0017.tif
n016_0013.tif
n033_0001.tif
n047_0020.tif

b047_0006.tif

is004_0001.tif
is004_0031.tif

iv017_0009.tif
iv025_0027.tif
iv027_0011.tif
iv044_0026.tif
iv052_0022.tif
iv070_0015.tif
'''


print 'TARGETS = ['
# Plot 4 images before stain normalisation
plt.figure(figsize=(14,3.5))
# Plot 4 images after stain normalisation
# plt.figure(figsize=(15,5))
for i, c in enumerate(classes):
    img = cv2.imread(path_prefix + 'SN/patches_512_256/validation/' + c + '/' + IMG_IDS[i] + '.tif')
#     img = cv2.imread(glob.glob(path_prefix + 'SN/patches_512_256/validation/' + c + '/*.tif')[ID])
    plt.subplot(1,4,1+i)
    plt.axis('off')
    plt.imshow(img)
plt.tight_layout(pad=-2.5)

# plt.savefig('./SN_patches.eps', format='eps', dpi=100)

plt.show()
# Out:
# TARGETS = [

# %%
######################################################################################
# Plot sample images from all 4 classes, before and after stain normalisation
######################################################################################
import matplotlib.pyplot as plt
import cv2
import glob


path_prefix = './../Dataset/SamplePatches/'
classes = ['Normal', 'Benign', 'InSitu', 'Invasive']

ID = 11 # 47
IMG_IDS = ['n033_0001', 
           'b033_0018', 
           'is011_0017', 
           'iv044_0026']

'''
n013_0017.tif
n016_0013.tif
                    n033_0001.tif
n047_0020.tif

b047_0006.tif
b033_0018.tif

is004_0001.tif
is004_0031.tif
is005_0022
is011_0010.tif
is011_0017.tif

iv017_0009.tif
iv025_0027.tif
iv027_0011.tif
                    iv044_0026.tif
 iv052_0022.tif
 iv070_0015.tif
'''


print 'TARGETS = ['
# Plot 4 images before stain normalisation
plt.figure(figsize=(14,3.5))
# Plot 4 images after stain normalisation
# plt.figure(figsize=(15,5))
for i, c in enumerate(classes):
    img = cv2.imread(path_prefix + 'SN/patches_512_256/validation/' + c + '/' + IMG_IDS[i] + '.tif')
#     img = cv2.imread(glob.glob(path_prefix + 'SN/patches_512_256/validation/' + c + '/*.tif')[ID])
    plt.subplot(1,4,1+i)
    plt.axis('off')
    plt.imshow(img)
plt.tight_layout(pad=-2.5)

# plt.savefig('./SN_patches.eps', format='eps', dpi=100)

plt.show()
# Out:
# TARGETS = [

# %%
# Copy patches; just to save these few ...

p_names = [
'n013_0017.tif',
'n016_0013.tif',
'n033_0001.tif',
'n047_0020.tif',

'b047_0006.tif',
'b033_0018.tif',

'is004_0001.tif',
'is004_0031.tif',
'is005_0022.tif',
'is011_0010.tif',
'is011_0017.tif',

'iv017_0009.tif',
'iv025_0027.tif',
'iv027_0011.tif',
'iv044_0026.tif',
'iv052_0022.tif',
'iv070_0015.tif'
]

import matplotlib.pyplot as plt
import cv2
import glob
from shutil import copyfile

path_org = '/home/janciovec/Desktop/Patches/'
path_new = './../Dataset/SamplePatches/'
classes = ['Normal', 'Benign', 'InSitu', 'Invasive']


for pn in p_names:
    if pn[0] == 'n':
        c = 'Normal'
    if pn[0] == 'b':
        c = 'Benign'
    if pn[1] == 's':
        c = 'InSitu'
    if pn[1] == 'v':
        c = 'Invasive'
    copyfile(path_org + 'SN/patches_512_256/validation/' + c + '/' + pn, 
             path_new + 'SN/patches_512_256/validation/' + c + '/' + pn)
    copyfile(path_org + 'notSN/patches_512_256/validation/' + c + '/' + pn, 
             path_new + 'notSN/patches_512_256/validation/' + c + '/' + pn)
