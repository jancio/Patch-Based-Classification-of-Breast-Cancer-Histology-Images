# %%
##################################################################################################
# Patch-based Classification of Breast Cancer Histology Images using CNNs
# LE48: MiniProject
# Jan Ondras (jo356), Trinity College
# 2017/2018
##################################################################################################
######################################################################################
# Plot sample images from all 4 classes, before and after stain normalisation
######################################################################################
import matplotlib.pyplot as plt
import cv2
import glob

path_prefix = './../Dataset/ICIAR2018_BACH_Challenge/'
classes = ['Normal', 'Benign', 'InSitu', 'Invasive']

ID = 47 # 47

# Plot 4 images before stain normalisation
plt.figure(figsize=(14,5))
for i, c in enumerate(classes):
    img = cv2.imread(glob.glob(path_prefix + 'Photos/' + c + '/*.tif')[ID])
    print glob.glob(path_prefix + 'Photos/' + c + '/*.tif')[ID]
    plt.subplot(2,4,1+i)
    plt.axis('off')
    plt.imshow(img)
# plt.tight_layout(pad=-3.)
# plt.show()

# Plot 4 images after stain normalisation
# plt.figure(figsize=(15,5))
for i, c in enumerate(classes):
    img = cv2.imread(glob.glob(path_prefix + 'Photos_SN/' + c + '/*.tif')[ID])
    plt.subplot(2,4,5+i)
    plt.axis('off')
    plt.imshow(img)
plt.tight_layout(pad=-3.)

plt.savefig('./SN_images.eps', format='eps', dpi=100)

plt.show()

# ./../Dataset/ICIAR2018_BACH_Challenge/Photos/Normal/n020.tif
# ./../Dataset/ICIAR2018_BACH_Challenge/Photos/Benign/b069.tif
# ./../Dataset/ICIAR2018_BACH_Challenge/Photos/InSitu/is070.tif
# ./../Dataset/ICIAR2018_BACH_Challenge/Photos/Invasive/iv048.tif
# Out:
# ./../Dataset/ICIAR2018_BACH_Challenge/Photos/Normal/n076.tif
# ./../Dataset/ICIAR2018_BACH_Challenge/Photos/Benign/b089.tif
# ./../Dataset/ICIAR2018_BACH_Challenge/Photos/InSitu/is062.tif
# ./../Dataset/ICIAR2018_BACH_Challenge/Photos/Invasive/iv072.tif
